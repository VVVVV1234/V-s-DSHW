# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# # Final Assignment
# - Course: Tools for Data Science
# - Full Name: Nguyen Dac Vinh
# - Country: Viet Nam
#
#
#
# ## Objectives
#
# In this final assignment, I will:
# * Create a Jupyter Notebook
# * Insert code and markdown cells
# * Share my notebook through GitHub

# %% [markdown]
# # Table of Contents
#
# 1. [Exercise 1 - Create a Jupyter Notebook](#Exercise-1)
# 2. [Exercise 2 - Create markdown cell with title of the notebook](#Exercise-2)
# 3. [Exercise 3 - Create a markdown cell for an introduction](#Exercise-3)
# 4. [Exercise 4 - Create a markdown cell to list data science languages](#Exercise-4)
# 5. [Exercise 5 - Create a markdown cell to list data science libraries](#Exercise-5)
# 6. [Exercise 6 - Create a markdown cell with a table of Data Science tools](#Exercise-6)
# 7. [Exercise 7 - Create a markdown cell introducing arithmetic expression examples](#Exercise-7)
# 8. [Exercise 8 - Create a code cell to multiply and add numbers](#Exercise-8)
# 9. [Exercise 9 - Create a code cell to convert minutes to hours](#Exercise-9)
# 10. [Exercise 10 - Insert a markdown cell to list Objectives](#Exercise-10)
# 11. [Exercise 11 - Create a markdown cell to indicate the Author's name](#Exercise-11)
# 12. [Exercise 12 - Share your notebook through GitHub](#Exercise-12)
# 13. [Exercise 13 -Take a screenshot of the first page of the notebook](#Exercise-13)

# %% [markdown]
# ## <span style="color:blue">Exercise 1</span>
#
# ### Create a Jupyter Notebook
#
# * Create a new Jupyter notebook called <span style="color:green">DataScienceEcosystem.ipynb</span>

# %% [markdown]
# ## <span style="color:blue">Exercise 2</span>
#
# ### Create markdown cell with title of the notebook
#
# * Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading.

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>2-title.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 2-title.png:![a screenshot of the markdown cell.png](attachment:389baade-f5f2-4db3-acd1-1fcfad6e324e.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 3</span>
# m
# ### Create a markdown cell for an introduction
#
# * Write an introductory sentence about the notebook such as the follows: **In this notebook, Data Science Tools and Ecosystem are summarized.**

# %% [markdown]
# **In this notebook, Data Science Tools and Ecosystem are summarized.**

# %% [markdown]
# **Objectives:**
#
#     + Catergories of Data Science Tools.
#     + Introduction of Python, R-language, and SQL.
#     + Introduction to Jupyter Notebooks.

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>3-intro.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 3-intro.png:![In this notebook, Data Science Tools and Ecosystem are summarized..png](attachment:8bbfa0fd-3e72-4e80-9bcb-9f07c45a85ef.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 4</span>
#
# ### Create a markdown cell to list data science languages
#
# * Start the cell with an overview line such as: **Some of the popular languages that Data Scientists use are:**
# * Then create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data science.

# %% [markdown]
# **Some of the popular languages that Data Scientists use are:**
#
#     1. Python
#     2. R
#     3. SQL

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>4-dslanguages.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 4-dslanguages.png:![4-dslanguages.png](attachment:076ec451-b12c-4cb9-af15-b139ab4d6e59.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 5</span>
#
# ### Create a markdown cell to list data science libraries
#
# * Add an overview line to the cell like: **Some of the commonly used libraries used by Data Scientists include:**.
# * Below this line add an ordered list listing 3 (or more) commonly used libraries in data science.

# %% [markdown]
# **Some of the commonly used libraries used by Data Scientists include:**
#
#     1. Pandas
#     2. Numpy
#     3. Matplotlib

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>5-dslibraries.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 5-dslibraries.png:![Screenshot 2024-10-07 at 12.02.39.png](attachment:c78ac2a6-fda3-4238-97f7-ffe89a48091c.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 6</span>
#
# ### Create a markdown cell with a table of Data Science tools
#
# * Create a single column table in this cell with the first row containing the header **Data Science Tools**.
# * The subsequent three rows in the table should indicate three development environment open source tools used in data science.

# %% [markdown]
# **Data Science Tools:**
# | Index | Data Science Tools |
# |------- | ------------------ |
# | 1 | Jupyter Notebook |
# | 2 | Jupyter Lab |
# | 3 | Spyder |

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>6-dstools.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 6-dstools.png:![Screenshot 2024-10-07 at 12.12.16.png](attachment:ae76d0b6-6caa-401a-aecd-f2a165a2afeb.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 7</span>
#
# ### Create a markdown cell introducing arithmetic expression examples
#
# * Add a line in this cell with H3 style heading with text like: **Below are a few examples of evaluating arithmetic expressions in Python.**

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>7-introarithmetic.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 7-introarithmetic.png:![Screenshot 2024-10-07 at 12.14.59.png](attachment:304fecd6-3e5c-4f83-9740-8d9c82e432b4.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 8</span>
#
# ### Create a code cell to multiply and add numbers
#
# * In this code cell evaluate the expression <code>(3*4)+5</code>.
# * Insert a comment line before the expression to explain the operation e.g.  <span style="color:green">_This a simple arithmetic expression to mutiply then add integers._</span>
# * Then execute the cell to ensure the expression returns the expected output of <code>17</code>.

# %%
(3*4)+5
#This a simple arithmetic expression to mutiply then add integers.
# Out:
# 17

# %% [markdown]
# * Take a screenshot of the code cell with output and name it as <code>8-multiplyandaddintegers.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 8-multiplyandaddintegers.png:![Screenshot 2024-10-07 at 12.18.13.png](attachment:657a9e87-a4f9-45fb-ad14-ac3f629499ab.png)
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 9</span>
#
# ### Create a code cell to convert minutes to hours
#
# * In this code cell write an expression that converts **200 minutes** into hours.
# * Insert a comment line before the expression to explain the operation e.g.  _This will convert 200 minutes to hours by diving by 60._
# * Run the cell to evaluate the expression.

# %%
# This will convert 200 minutes to hours by diving by 60.
x = 200/60
print('The results: 200 minutes = {} hours.'.format(round(x,2)))
# Out:
# The results: 200 minutes = 3.33 hours.

# %% [markdown]
# * Take a screenshot of the code cell with output and name it as <code>9-hourstominutes.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 9-hourstominutes.png:![Screenshot 2024-10-07 at 12.27.23.png](attachment:843c8859-2efd-4690-8019-7b879b52b9bd.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 10</span>
#
# ### Insert a markdown cell to list Objectives
#
# * Below the introduction cell created in **Exercise 3**, insert a new markdown cell to list the objectives that this notebook covered (_i.e. some of the key takeaways from the course_).
# * In this new cell start with an introductory line titled: **Objectives:** in bold font. Then using _an unordered list (bullets)_ indicate 3 to 5 items covered in this notebook, such as List popular languages for Data Science.

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>10-objectives.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 10-objectives.png:![Screenshot 2024-10-07 at 12.29.52.png](attachment:8bd2030b-a02b-494a-814b-b3cf393e5069.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 11</span>
#
# ### Create a markdown cell to indicate the Author's name
#
# * In this markdown cell markdown cell include the following text **Author in H2 style heading**. Include your name as regular text below the word Author.

# %% [markdown]
# ## Author
#
# [Nguyen Dac Vinh](https://www.linkedin.com/in/vinhdac/)
#
# © Copyright IBM Corporation. All rights reserved.

# %% [markdown]
# * Take a screenshot of the markdown cell and name it as <code>11-authordetails.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 11-authordetails.png:![Screenshot 2024-10-07 at 12.37.23.png](attachment:ffbe1687-c9a1-49dd-9b1b-e38e42a90ca9.png)
#
# </details>

# %% [markdown]
# ## <span style="color:blue">Exercise 11</span>
#
# ### Share your notebook through GitHub
#
# * Upload your notebook to a public respository on GitHub.

# %% [markdown]
# ## <span style="color:blue">Exercise 13</span>
#
# ### Take a screenshot of the first page
#
# * Take a screenshot of the first page of the notebook and save it as <code>1-notebook.png</code> _(Images can be saved with either the .jpg or .png extension.)_

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 1-notebook.png:![Screenshot 2024-10-07 at 13.15.13.png](attachment:10c9b87d-a948-4e7f-bcb8-1988a80d3b7d.png)
#
# </details>

# %% [markdown]
# <p style="text-align:center">- THE END -</p>
